# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot
chi_df = pd.read_csv("chicago_demo.csv",
                         keep_default_na=False, na_values=[""])
chi_df
# Out:
#     lab_report_date  cases_total  deaths_total  cases_age_0_17  \
# 0         7/17/2020            1             1               0
# 1         7/16/2020           39             0               1
# 2         7/15/2020           98             4              15
# 3         7/14/2020          234             3              36
# 4         7/13/2020          255             4              26
# ..              ...          ...           ...             ...
# 132        3/7/2020            3             0               0
# 133        3/6/2020            3             0               0
# 134        3/5/2020            1             0               0
# 135       2/28/2020            1             0               0
# 136       1/21/2020            1             0               0
#
#      cases_age_18_29  cases_age_30_39  cases_age_40_49  cases_age_50_59  \
# 0                  1                0                0                0
# ...

# %%
chicase_by_race_df = chi_df[["lab_report_date",
                      "cases_total",
                      "cases_latinx",
                      "cases_asian_non_latinx",
                      "cases_black_non_latinx",
                      "cases_white_non_latinx",
                      "cases_other_non_latinx",
                     "cases_unknown_race_eth"]]

# Clean the data by dropping empty row
chicase_by_race_df = chicase_by_race_df.dropna(how = "any")

# Change data type from str to int
cols = chicase_by_race_df.columns.drop("lab_report_date")
chicase_by_race_df[cols] = chicase_by_race_df[cols].apply(pd.to_numeric, errors='coerce')

# Remove time from date&time variable
chicase_by_race_df["lab_report_date"] = pd.to_datetime(chicase_by_race_df["lab_report_date"]).dt.date

# %%
il_df = pd.read_csv("ILCovid.csv",
                         keep_default_na=False, na_values=[""])
il_df
# Out:
#          Date State  Cases_Total  Cases_White  Cases_Black  Cases_LatinX  \
# 0   7/15/2020    IL       157825        34463        26330         49483
# 1   7/12/2020    IL       155048        33468        25828         48999
# 2    7/8/2020    IL       150554        31974        25072         48116
# 3    7/5/2020    IL       148373        31143        24691         47679
# 4    7/1/2020    IL       144013        30175        24191         46832
# 5   6/28/2020    IL       141723        29505        23774         46213
# 6   6/24/2020    IL       138540        28469        23223         45294
# 7   6/21/2020    IL       136762        27901        22941         44647
# 8   6/17/2020    IL       134185        26830        22296         43765
# 9   6/14/2020    IL       132543        26338        22004         42950
# 10  6/10/2020    IL       129837        25574        21575         41721
# 11   6/7/2020    IL       127757        25020        21192         40854
# ...

# %%
# Case by race dataframe
case_by_race_df = il_df[["Date",
                      "Cases_Total",
                      "Cases_LatinX",
                      "Cases_Asian",
                      "Cases_Black",
                      "Cases_White",
                      "Cases_AIAN",
                      "Cases_NHPI",
                       "Cases_Other"]]

# Clean the data by dropping empty row
case_by_race_df = case_by_race_df.dropna(how = "any")

# Change data type from str to int
cols = case_by_race_df.columns.drop("Date")
case_by_race_df[cols] = case_by_race_df[cols].apply(pd.to_numeric, errors='coerce')

# Remove time from date&time variable
case_by_race_df["Date"] = pd.to_datetime(case_by_race_df["Date"]).dt.date

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-96b208e59dc6> in <module>
#       4 chicase_by_race_df['hue']=2
#       5 res=pd.concat([case_by_race_df,chicase_by_race_df])
# ----> 6 sns.barplot(x='x',y='y',data=res,hue='hue')
#       7 plot.show()
#
# C:\Python\Python38\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ...
