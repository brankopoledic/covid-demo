# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import xlrd

# %%
excel_data_df = pd.read_excel('Line.xlsx')
ildf = pd.DataFrame(excel_data_df)
ildf.head()
# Out:
#   Date  Chi Total Cases  Chi Black Cases  Chi Asian Cases  Chi White Cases  \
# 0  Mar             4437             2056              157             1032
# 1  Apr            21503             5882              575             2655
# 2  May            21199             3591              330             1831
# 3  Jun             6214             1192               99              778
# 4  Jul             3028              779               61              523
#
#    Chi Other Cases  Chi Latin Cases  IL Total Cases  IL White Cases  \
# 0              146              715             NaN             NaN
# 1             1023             7543        159723.0         38230.0
# 2              787             9593        831649.0        169015.0
# 3              221             2531       1065177.0        213765.0
# 4              137              906        755813.0        161223.0
#
#    IL Black Cases  IL Latin Cases  IL Asian Cases  IL Other Cases
# ...

# %%
ildf.plot()
# Out:
# <AxesSubplot:>

# %%
# Case by race dataframe
cbr_df = ildf[["Chi White Cases",
                "Chi Black Cases",
                "Chi Latin Cases",
                "IL White Cases",
                "IL Black Cases",
                 "IL Latin Cases",
                  "Date"]]

# Clean the data by dropping empty row
cbr_df = cbr_df.dropna(how = "any")

# %%
cbr_df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Case by race dataframe
ccbr_df = ildf[["Chi White Cases",
                "IL White Cases",
                  "Date"]]

# Clean the data by dropping empty row
ccbr_df = ccbr_df.dropna(how = "any")

# %%
ccbr_df.plot()
# Out:
# <AxesSubplot:>
