# %%
import pandas as pd

covid_il = pd.read_csv("csv_files/il_covid_data.csv")
covid_il.head()
# Out:
#    Demo_id  Date_Object        Date State  Cases_Total  Cases_White  \
# 0       16     20200715  2020-07-15    IL       157825        34463
# 1       72     20200712  2020-07-12    IL       155048        33468
# 2      128     20200708  2020-07-08    IL       150554        31974
# 3      184     20200705  2020-07-05    IL       148373        31143
# 4      240     20200701  2020-07-01    IL       144013        30175
#
#    Cases_Black  Cases_LatinX  Cases_Asian  Cases_AIAN  ...  Deaths_LatinX  \
# 0        26330         49483         4373         228  ...           1491
# 1        25828         48999         4317         226  ...           1482
# 2        25072         48116         4249         225  ...           1460
# 3        24691         47679         4209         224  ...           1448
# 4        24191         46832         4163         219  ...           1435
#
#    Deaths_Asian  Deaths_AIAN  Deaths_NHPI  Deaths_Multiracial  Deaths_Other  \
# ...

# %%
# view shape of df
covid_il.shape
# Out:
# (28, 30)

# %%
# convert date column to datetime type
covid_il["Date"] = pd.to_datetime(covid_il["Date"])
covid_il["Date"]
# Out:
# 0    2020-07-15
# 1    2020-07-12
# 2    2020-07-08
# 3    2020-07-05
# 4    2020-07-01
# 5    2020-06-28
# 6    2020-06-24
# 7    2020-06-21
# 8    2020-06-17
# 9    2020-06-14
# 10   2020-06-10
# 11   2020-06-07
# 12   2020-06-03
# 13   2020-05-31
# 14   2020-05-27
# 15   2020-05-24
# 16   2020-05-20
# 17   2020-05-17
# 18   2020-05-13
# 19   2020-05-10
# 20   2020-05-06
# 21   2020-05-03
# 22   2020-04-29
# 23   2020-04-26
# 24   2020-04-22
# 25   2020-04-19
# 26   2020-04-15
# 27   2020-04-12
# Name: Date, dtype: datetime64[ns]

# %%
# create a month column from date column
covid_il["Month"] = covid_il["Date"].dt.month_name()
covid_il.head()
# Out:
#    Demo_id  Date_Object       Date State  Cases_Total  Cases_White  \
# 0       16     20200715 2020-07-15    IL       157825        34463
# 1       72     20200712 2020-07-12    IL       155048        33468
# 2      128     20200708 2020-07-08    IL       150554        31974
# 3      184     20200705 2020-07-05    IL       148373        31143
# 4      240     20200701 2020-07-01    IL       144013        30175
#
#    Cases_Black  Cases_LatinX  Cases_Asian  Cases_AIAN  ...  Deaths_Asian  \
# 0        26330         49483         4373         228  ...           346
# 1        25828         48999         4317         226  ...           343
# 2        25072         48116         4249         225  ...           337
# 3        24691         47679         4209         224  ...           329
# 4        24191         46832         4163         219  ...           327
#
#    Deaths_AIAN  Deaths_NHPI  Deaths_Multiracial  Deaths_Other  Deaths_Unknown  \
# ...

# %%
# reorder columns so month is at the front
covid_il_data = covid_il[["Month","Date", "State", "Cases_Total", "Cases_White","Cases_Black","Cases_LatinX","Cases_Asian","Cases_AIAN","Cases_NHPI","Cases_Other","Cases_Unknown",
                          "Deaths_Total",'Deaths_White',"Deaths_Black","Deaths_LatinX","Deaths_Asian","Deaths_AIAN","Deaths_NHPI","Deaths_Other","Deaths_Unknown"]]
covid_il_data.head()
# Out:
#   Month       Date State  Cases_Total  Cases_White  Cases_Black  Cases_LatinX  \
# 0  July 2020-07-15    IL       157825        34463        26330         49483
# 1  July 2020-07-12    IL       155048        33468        25828         48999
# 2  July 2020-07-08    IL       150554        31974        25072         48116
# 3  July 2020-07-05    IL       148373        31143        24691         47679
# 4  July 2020-07-01    IL       144013        30175        24191         46832
#
#    Cases_Asian  Cases_AIAN  Cases_NHPI  ...  Cases_Unknown  Deaths_Total  \
# 0         4373         228         390  ...          36731          7427
# 1         4317         226         385  ...          36106          7388
# 2         4249         225         384  ...          34990          7309
# 3         4209         224         379  ...          34555          7230
# 4         4163         219         373  ...          32677          6951
#
# ...

# %%
# get count of null values and location
covid_il_data.isnull().sum()
# Out:
# Month             0
# Date              0
# State             0
# Cases_Total       0
# Cases_White       0
# Cases_Black       0
# Cases_LatinX      0
# Cases_Asian       0
# Cases_AIAN        0
# Cases_NHPI        0
# Cases_Other       0
# Cases_Unknown     0
# Deaths_Total      0
# Deaths_White      0
# Deaths_Black      0
# Deaths_LatinX     0
# Deaths_Asian      0
# Deaths_AIAN       0
# Deaths_NHPI       0
# Deaths_Other      0
# Deaths_Unknown    0
# dtype: int64

# %%
# normalize data 
state_population = 12600
white_cases_per_100 = (covid_il_data["Cases_White"]/covid_il_data["Cases_Total"]) * 100
white_cases_per_100
# Out:
# 0     21.836211
# 1     21.585573
# 2     21.237563
# 3     20.989668
# 4     20.952970
# 5     20.818780
# 6     20.549300
# 7     20.401135
# 8     19.994783
# 9     19.871287
# 10    19.697005
# 11    19.584054
# 12    19.484778
# 13    19.479461
# 14    19.499414
# 15    19.635734
# 16    20.166703
# 17    20.403223
# 18    20.551843
# 19    21.082826
# 20    21.703893
# 21    22.058895
# 22    23.187370
# 23    23.750085
# 24    24.418936
# 25    24.883882
# 26    24.913593
# 27    25.004796
# dtype: float64

# %%
# group data by month
march_data = covid_il_data.loc[covid_il_data["Month"] == "March", :]
april_data = covid_il_data.loc[covid_il_data["Month"] == "April", :]
may_data = covid_il_data.loc[covid_il_data["Month"] == "May", :]
june_data = covid_il_data.loc[covid_il_data["Month"] == "June", :]
july_data = covid_il_data.loc[covid_il_data["Month"] == "July", :]

# %%
import matplotlib.pyplot as plt

# %%
# total cases bar graph

y_value = "Total Cases"

month_and_total_cases = covid_il_data[["Month","Cases_Total"]]
month_and_total_cases = month_and_total_cases.set_index("Month")

month_and_total_cases.plot(kind="bar", figsize=(20,3))
plt.title("Total Covid Cases in IL by Month")
plt.ylabel(f"{y_value}")
plt.show();

# %%
# total Deaths bar graph

y_value = "Total Deaths"

month_and_total_cases = covid_il_data[["Month","Deaths_Total"]]
month_and_total_cases = month_and_total_cases.set_index("Month")

month_and_total_cases.plot(kind="bar", figsize=(20,3))
plt.title("Total Covid Deaths in IL by Month")
plt.ylabel(f"{y_value}")
plt.show();
