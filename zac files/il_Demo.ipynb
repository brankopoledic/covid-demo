# %%
import pandas as pd
import numpy as np

file_path = "Demo.csv"

covid = pd.read_csv(file_path)

covid.head(25)
# Out:
#         Date State Cases_Total Cases_White  Cases_Black  Cases_LatinX  \
# 0   20200715    AK        1631         672         39.0           NaN
# 1   20200715    AL       59067       19231      18335.0           NaN
# 2   20200715    AR       30297       14673       6444.0           NaN
# 3   20200715    AS         NaN         NaN          NaN           NaN
# 4   20200715    AZ      131354       21232       2882.0       30361.0
# 5   20200715    CA      347634       39528       9697.0      122179.0
# 6   20200715    CO       38155       11869       1784.0       12957.0
# 7   20200715    CT       47636       17043       6273.0        9047.0
# 8   20200715    DC       11026        2253       5431.0           NaN
# 9   20200715    DE       13050        4241       3333.0        3498.0
# 10  20200715    FL      301810       63104      42761.0       76269.0
# 11  20200715    GA      127834       29953      33489.0       18261.0
# ...

# %%
# view columns of DF
for col in covid.columns:
    print(col)
# Out:
# Date
# State
# Cases_Total
# Cases_White
# Cases_Black
# Cases_LatinX
# Cases_Asian
# Cases_AIAN
# Cases_NHPI
# Cases_Multiracial
# Cases_Other
# Cases_Unknown
# Cases_Ethnicity_Hispanic
# Cases_Ethnicity_NonHispanic
# Cases_Ethnicity_Unknown
# Deaths_Total
# Deaths_White
# Deaths_Black
# Deaths_LatinX
# Deaths_Asian
# Deaths_AIAN
# Deaths_NHPI
# Deaths_Multiracial
# Deaths_Other
# Deaths_Unknown
# Deaths_Ethnicity_Hispanic
# Deaths_Ethnicity_NonHispanic
# Deaths_Ethnicity_Unknown

# %%
# new dataframe for state IL
covid_il = covid.loc[covid["State"] == "IL", :]
covid_il
# Out:
#           Date State Cases_Total Cases_White  Cases_Black  Cases_LatinX  \
# 16    20200715    IL      157825       34463      26330.0       49483.0
# 72    20200712    IL      155048       33468      25828.0       48999.0
# 128   20200708    IL      150554       31974      25072.0       48116.0
# 184   20200705    IL      148373       31143      24691.0       47679.0
# 240   20200701    IL      144013       30175      24191.0       46832.0
# 296   20200628    IL      141723       29505      23774.0       46213.0
# 352   20200624    IL      138540       28469      23223.0       45294.0
# 408   20200621    IL      136762       27901      22941.0       44647.0
# 464   20200617    IL      134185       26830      22296.0       43765.0
# 520   20200614    IL      132543       26338      22004.0       42950.0
# 576   20200610    IL      129837       25574      21575.0       41721.0
# 632   20200607    IL      127757       25020      21192.0       40854.0
# ...
